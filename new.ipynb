# %%
import pandas as pd

# %%
notes = pd.read_csv('notes.csv')
display(notes.head(20))
# Out:
#                                             File Path  Size (Bytes) Timestamp
# 0                    Notes/DSA/Linked Lists/Doubly LL           0.0       NaN
# 1             Notes/DSA/Linked Lists/Traversal of DLL           0.0       NaN
# 2   Notes/DSA/Linked Lists/Insertion at beginning ...           0.0       NaN
# 3        Notes/DSA/Linked Lists/Deletion in Singly LL           0.0       NaN
# 4   Notes/DSA/Linked Lists/Deletion at a given pos...           0.0       NaN
# 5   Notes/DSA/Linked Lists/Introduction to Linked ...           0.0       NaN
# 6   Notes/DSA/Linked Lists/Deletion at beginning o...           0.0       NaN
# 7                  Notes/DSA/Linked Lists/Grounded LL           0.0       NaN
# 8       Notes/DSA/Linked Lists/Traversal of Singly LL           0.0       NaN
# 9      Notes/DSA/Linked Lists/Deletion in Circular LL           0.0       NaN
# 10      Notes/DSA/Linked Lists/Insertion in Singly LL           0.0       NaN
# ...

# %%
que = pd.read_csv('questions.csv')
display(que.head(20))
# Out:
#                                             File Path  Size (Bytes) Timestamp
# 0                                       Questions/GCD           0.0       NaN
# 1                    Questions/Sliding Window Maximum           0.0       NaN
# 2                         Questions/Maximal Rectangle           0.0       NaN
# 3                          Questions/Armstrong Number           0.0       NaN
# 4                           Questions/Reverse Integer           0.0       NaN
# 5                Questions/Leetcode/Palindrome Number           0.0       NaN
# 6                      Questions/Leetcode/Move Zeroes           0.0       NaN
# 7                         Questions/celebrity problem           0.0       NaN
# 8   Questions/Leetcode/Intersection of Two Linked ...           0.0       NaN
# 9             Questions/Leetcode/Odd Even Linked List           0.0       NaN
# 10                   Questions/Leetcode/Sudoku Solver           0.0       NaN
# ...
